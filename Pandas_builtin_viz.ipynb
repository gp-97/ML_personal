# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('ref/07-Pandas-Built-in-Data-Viz/df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('ref/07-Pandas-Built-in-Data-Viz/df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
plt.hist(df1['A'])
# Out:
# (array([  1.,  13.,  35., 133., 271., 279., 173.,  80.,  12.,   3.]),
#  array([-3.69320113, -2.98265739, -2.27211365, -1.56156991, -0.85102617,
#         -0.14048243,  0.57006131,  1.28060505,  1.99114879,  2.70169253,
#          3.41223627]),
#  <a list of 10 Patch objects>)

# %%
df1['A'].hist(bins=20)

# %%
df1.plot.hist(bins=30)

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ce40ab214708> in <module>
# ----> 1 df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwds)
#    3004             >>> lines = df.plot.line(x='pig', y='horse')
#    3005         """
# -> 3006         return self(kind='line', x=x, y=y, **kwds)
#    3007
#    3008     def bar(self, x=None, y=None, **kwds):
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
sns.lineplot(x=df1.index,y='B',data=df1)

# %%
df1.plot.scatter(x='A',y="B",c='C',cmap='ocean')

# %%
df1.plot.scatter(x='A',y="B",c='C',s=df1['C']*100,cmap='magma')

# %%
df = pd.DataFrame(np.random.randn(500,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -2.010331 -0.096781
# 1 -1.648218  0.140273
# 2 -1.286322 -2.141072
# 3  0.006241 -0.644478
# 4 -1.702048  0.219999

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')

# %%
df2.plot.density()
